# %% [markdown]
# **Import packages and dataset**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random 
import seaborn as sns
# %matplotlib inline

# %%
# Importing USA Housing.csv
data = pd.read_csv("Housing_Data.csv")
data.head()
# Out:
#    Avg. Area Income  ...                                            Address
# 0      79545.458574  ...  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1      79248.642455  ...  188 Johnson Views Suite 079\nLake Kathleen, CA...
# 2      61287.067179  ...  9127 Elizabeth Stravenue\nDanieltown, WI 06482...
# 3      63345.240046  ...                          USS Barnett\nFPO AP 44820
# 4      59982.197226  ...                         USNS Raymond\nFPO AE 09386
#
# [5 rows x 7 columns]

# %% [markdown]
# **Exploratory Data Analysis**

# %%
data.columns
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Avg. Area Number of Bedrooms', 'Area Population', 'Price', 'Address'],
#       dtype='object')

# %%
data.describe(include='all')
# Out:
#         Avg. Area Income  ...                                Address
# count        5000.000000  ...                                   5000
# unique               NaN  ...                                   5000
# top                  NaN  ...  PSC 6671, Box 5919\nAPO AA 13384-7992
# freq                 NaN  ...                                      1
# mean        68583.108984  ...                                    NaN
# std         10657.991214  ...                                    NaN
# min         17796.631190  ...                                    NaN
# 25%         61480.562388  ...                                    NaN
# 50%         68804.286404  ...                                    NaN
# 75%         75783.338666  ...                                    NaN
# max        107701.748378  ...                                    NaN
#
# [11 rows x 7 columns]

# %%
data.shape
# Out:
# (5000, 7)

# %%
data.dtypes
# Out:
# Avg. Area Income                float64
# Avg. Area House Age             float64
# Avg. Area Number of Rooms       float64
# Avg. Area Number of Bedrooms    float64
# Area Population                 float64
# Price                           float64
# Address                          object
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Avg. Area Income              5000 non-null   float64
#  1   Avg. Area House Age           5000 non-null   float64
#  2   Avg. Area Number of Rooms     5000 non-null   float64
#  3   Avg. Area Number of Bedrooms  5000 non-null   float64
#  4   Area Population               5000 non-null   float64
#  5   Price                         5000 non-null   float64
#  6   Address                       5000 non-null   object
# dtypes: float64(6), object(1)
# memory usage: 273.6+ KB

# %%
data['Price'].head(10)
# Out:
# 0    1.059034e+06
# 1    1.505891e+06
# 2    1.058988e+06
# 3    1.260617e+06
# 4    6.309435e+05
# 5    1.068138e+06
# 6    1.502056e+06
# 7    1.573937e+06
# 8    7.988695e+05
# 9    1.545155e+06
# Name: Price, dtype: float64

# %%
data['Avg. Area Number of Rooms']
# Out:
# 0       7.009188
# 1       6.730821
# 2       8.512727
# 3       5.586729
# 4       7.839388
#           ...
# 4995    6.137356
# 4996    6.576763
# 4997    4.805081
# 4998    7.130144
# 4999    6.792336
# Name: Avg. Area Number of Rooms, Length: 5000, dtype: float64

# %%
data['Avg. Area House Age'].head(14)
# Out:
# 0     5.682861
# 1     6.002900
# 2     5.865890
# 3     7.188236
# 4     5.040555
# 5     4.988408
# 6     6.025336
# 7     6.989780
# 8     5.362126
# 9     4.423672
# 10    8.093513
# 11    4.496513
# 12    7.671755
# 13    6.919535
# Name: Avg. Area House Age, dtype: float64

# %%
data['Avg. Area Income'].describe()
# Out:
# count      5000.000000
# mean      68583.108984
# std       10657.991214
# min       17796.631190
# 25%       61480.562388
# 50%       68804.286404
# 75%       75783.338666
# max      107701.748378
# Name: Avg. Area Income, dtype: float64

# %%
data['Price'].describe()
# Out:
# count    5.000000e+03
# mean     1.232073e+06
# std      3.531176e+05
# min      1.593866e+04
# 25%      9.975771e+05
# 50%      1.232669e+06
# 75%      1.471210e+06
# max      2.469066e+06
# Name: Price, dtype: float64

# %%
data['Avg. Area Income'].tail(16)
# Out:
# 4984    62623.359828
# 4985    75117.042949
# 4986    71060.406015
# 4987    65729.222330
# 4988    67637.840665
# 4989    47965.406896
# 4990    52723.876555
# 4991    74102.191890
# 4992    87499.125743
# 4993    69639.140896
# 4994    73060.846226
# 4995    60567.944140
# 4996    78491.275435
# 4997    63390.686886
# 4998    68001.331235
# 4999    65510.581804
# Name: Avg. Area Income, dtype: float64

# %%
from pandas.plotting import register_matplotlib_converters 
register_matplotlib_converters()

plt.figure(figsize=(10,7))
plt.scatter(data.index, data["Area Population"]);

# %%
data.describe()
# Out:
#        Avg. Area Income  Avg. Area House Age  ...  Area Population         Price
# count       5000.000000          5000.000000  ...      5000.000000  5.000000e+03
# mean       68583.108984             5.977222  ...     36163.516039  1.232073e+06
# std        10657.991214             0.991456  ...      9925.650114  3.531176e+05
# min        17796.631190             2.644304  ...       172.610686  1.593866e+04
# 25%        61480.562388             5.322283  ...     29403.928702  9.975771e+05
# 50%        68804.286404             5.970429  ...     36199.406689  1.232669e+06
# 75%        75783.338666             6.650808  ...     42861.290769  1.471210e+06
# max       107701.748378             9.519088  ...     69621.713378  2.469066e+06
#
# [8 rows x 6 columns]

# %%
sns.jointplot(data=data,x="Price", y="Area Population", kind="hex")

# %%
sns.set(style='whitegrid', palette="deep", font_scale=1.1, rc={"figure.figsize": [10, 5]})
sns.distplot(
    data['Price'], norm_hist=False, kde=False, bins=20, hist_kws={"alpha": 1}
).set(xlabel='Price', ylabel='Avg. Area House Age');
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.jointplot(x=data["Avg. Area House Age"] ,y=data["Price"], data=data, kind='kde')

# %% [markdown]
# **Train and test data**

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
X = data[['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
               'Avg. Area Number of Bedrooms', 'Area Population']]
y = data['Price']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,train_size = 0.8, test_size=0.2)

# %%
cl = LinearRegression()
cl.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
predictions = cl.predict(X_test)
plt.scatter(y_test,predictions)

# %% [markdown]
# **`Linear Regression model `**

# %%
import matplotlib.pyplot as plt
from scipy import stats

# %%
x = data['Price']
y = data['Avg. Area House Age']

# %%
slope, intercept, r, p, std_err = stats.linregress(x, y)
def myfunc(x):
  return slope * x + intercept
  mymodel = list(map(myfunc, x))

# %%
plt.scatter(x, y)
plt.show()

# %% [markdown]
# **evaluation metric**

# %%
predictions = cl.predict(X_test)

# %%
plt.scatter(y_test,predictions)

# %%
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 82133.32387979915
# RMSE: 100214.7420872543

# %%
plt.scatter(x=predictions,y=y_test-predictions)

# %% [markdown]
# **Repeat Step 2, 3 and 4**

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
x1 = data[['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
               'Avg. Area Number of Bedrooms', 'Area Population']]
y = data['Price']

# %%
x1_train, x1_test, y_train, y_test = train_test_split(x1, y,train_size =1/95 , test_size= 1/5)

# %%
lm = LinearRegression()
lm.fit(x1_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
predictions = lm.predict(x1_test)
plt.scatter(y_test,predictions)

# %%
import matplotlib.pyplot as plt
from scipy import stats

# %%
x = data['Avg. Area Number of Rooms']
y = data['Avg. Area Number of Bedrooms']

# %%
slope, intercept, r, p, std_err = stats.linregress(x, y)
def myfunc(x):
  return slope * x + intercept
  mymodel = list(map(myfunc, x))

# %%
plt.scatter(x, y)
plt.show()

# %%
predictions = lm.predict(x1_test)

# %%
plt.scatter(y_test,predictions)

# %%
from sklearn import metrics
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# RMSE: 103632.00972098172

# %% [markdown]
# **Explain which model do you think is better and why?**

# %% [markdown]
# I think is linear model is better, because the linear model trained on polynomial features is able to exactly recover the input polynomial coefficients.so I import dependencies, for linear regression and use sklearn and import linear regression from it. and then initialize Linear Regression to variable cl or lm. when using a different method, which is very important for weak prediction models such as this case.
